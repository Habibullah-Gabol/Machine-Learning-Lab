# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([20, 30, 40, 50, 60])

# %%
slope = 1
bias = 1
lr = 0.1

# %%
# class LinearRegression:
#     def __init__(self):
#         self.slope = None
#         self.intercept = None

# %%
# y_pred = [bias + slope * x for x in x]
y_pred = slope * x + bias

# %%
y_pred
# Out:
# array([2, 3, 4, 5, 6])

# %%
y
# Out:
# array([20, 30, 40, 50, 60])

# %%
error = y_pred - y

# %%
error
# Out:
# array([-18, -27, -36, -45, -54])

# %%
cost = np.mean((y_pred - y) ** 2) / 2
cost
# Out:
# np.float64(729.0)

# %%
grad_for_slope = np.mean(y_pred - y)
grad_for_slope
# Out:
# np.float64(-36.0)

# %%
grad_for_bias = np.mean(y_pred - y) * x
grad_for_bias
# Out:
# array([ -36.,  -72., -108., -144., -180.])

# %%
slope = slope - lr * (grad_for_slope)
slope
# Out:
# np.float64(8.2)

# %%
bias = bias - lr * (grad_for_bias)
bias
# Out:
# array([ 8.2, 15.4, 22.6, 29.8, 37. ])
